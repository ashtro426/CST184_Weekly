# %%
# !pip3 install matplotlib pandas
# Out:
# Requirement already satisfied: matplotlib in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (3.10.6)
# Requirement already satisfied: pandas in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# --- BAR CHART: CO₂ EMISSIONS ---

import matplotlib.pyplot as plt
import pandas as pd

# Dictionary of emissions per capita (in tonnes)
emissions = {"Nepal": 0.3, "Kenya": 0.5, "Brazil": 2.1}

# Bar chart using matplotlib
plt.bar(emissions.keys(), emissions.values())
plt.title("CO₂ Emissions per Capita")
plt.xlabel("Country")
plt.ylabel("Tonnes")
plt.grid(True)
plt.show()

print("\n---\n")

# --- SCATTERPLOT: POPULATION VS ENERGY USE ---

population = [30, 54, 213]  # in millions
energy_use = [400, 520, 650]  # in TWh
countries = ["Nepal", "Kenya", "Brazil"]

plt.scatter(population, energy_use)

# Add labels to each point
for i, country in enumerate(countries):
    plt.text(population[i], energy_use[i], country)

plt.title("Population vs Energy Use")
plt.xlabel("Population (millions)")
plt.ylabel("Energy Use (TWh)")
plt.grid(True)
plt.show()

print("\n---\n")

# --- PANDAS PLOT: REPEATING BAR CHART ---

# Create a simple DataFrame
df = pd.DataFrame({
    "Country": ["Nepal", "Kenya", "Brazil"],
    "Emissions": [0.3, 0.5, 2.1]
})

# Bar chart using pandas
df.plot(x="Country", y="Emissions", kind="bar", legend=False)
plt.title("Emissions via pandas")
plt.ylabel("Tonnes")
plt.grid(True)
plt.show()
# Out:
# ---
# ---
