# %%
import pandas as pd
df = pd.read_csv("renewable_energy.csv")
df.head()
# Out:
#    Country         Region  Population  %Renewable  CO2_Emissions
# 0    Nepal           Asia          30          89            0.3
# 1    Kenya         Africa          54          76            0.5
# 2   Brazil  South America         213          45            2.1
# 3    India           Asia        1400          24            1.9
# 4  Germany         Europe          83          48            9.6

# %%
print(df[['Country', '%Renewable']])
# Out:
#      Country  %Renewable
# 0      Nepal          89
# 1      Kenya          76
# 2     Brazil          45
# 3      India          24
# 4    Germany          48
# 5     Norway          98
# 6  Australia          30
# 7    Nigeria          17
# 8    Vietnam          64
# 9     Mexico          41

# %%
high_renewable = df[df["%Renewable"] > 50]
high_renewable
# Out:
#    Country  Region  Population  %Renewable  CO2_Emissions
# 0    Nepal    Asia          30          89            0.3
# 1    Kenya  Africa          54          76            0.5
# 5   Norway  Europe           5          98            0.1
# 8  Vietnam    Asia          98          64            1.2

# %%
high_renewable = df[df["%Renewable"] > 70]
high_renewable
# Out:
#   Country  Region  Population  %Renewable  CO2_Emissions
# 0   Nepal    Asia          30          89            0.3
# 1   Kenya  Africa          54          76            0.5
# 5  Norway  Europe           5          98            0.1

# %%
high_set = set(high_renewable["Country"])
print("Countries with > 50% renewable energy:", high_set)
print("Cardinality:", len(high_set))
# Out:
# Countries with > 50% renewable energy: {'Norway', 'Kenya', 'Nepal'}
# Cardinality: 3

# %%
emissions_dict = dict(zip(df["Country"], df["CO2_Emissions"]))
print(emissions_dict["Brazil"])
# Out:
# 2.1

# %%
import matplotlib.pyplot as plt

plt.bar(emissions_dict.keys(), emissions_dict.values())
plt.xticks(rotation=45)
plt.title("CO₂ Emissions per Capita by Country")
plt.ylabel("Tonnes")
plt.grid(True)
plt.show()

# %%
plt.bar(emissions_dict.keys(), emissions_dict.values(), color = 'green')
plt.xticks(rotation=45)
plt.title("CO₂ Emissions per Capita by Country")
plt.ylabel("Tonnes")
plt.grid(True)
plt.show()

# %%
plt.scatter(df["Population"], df["%Renewable"])

for i in range(len(df)):
    plt.text(df["Population"][i], df["%Renewable"][i], df["Country"][i])

plt.title("Population vs % Renewable Energy Use")
plt.xlabel("Population (millions)")
plt.ylabel("% Renewable")
plt.grid(True)
plt.show()

# %%
subset = df[df["%Renewable"] > 60]
subset.to_csv("high_renewable_countries.csv", index=False)

# %%
Reflection questions
Which regions have the highest renewable energy adoption? Norway Shows the highest renewable energy adoption
Is there a relationship between population size and renewable use? smaller countries seem to have higher renewable adoption, while larger countries have lower adoption
