# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# Week 4 – Box Plot Visualization for Categorical Features

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

# Step 1: Simulated dataset
regions = ['Asia', 'Africa', 'Europe', 'South America']
energy_types = ['Solar', 'Wind', 'Hydro']

# Generate combinations
data = []
for region in regions:
    for energy in energy_types:
        for _ in range(10):  # 10 data points per category
            co2 = random.gauss(mu=5 if energy == 'Hydro' else 3, sigma=1.5)
            data.append([region, energy, round(max(co2, 0.2), 2)])  # Ensure no negative emissions

df = pd.DataFrame(data, columns=['region', 'energy_type', 'co2_emissions'])

# Step 2: Create new combined category
df['region_energy'] = df['region'] + "_" + df['energy_type']

# Step 3: Plot box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='region_energy', y='co2_emissions')
plt.title("CO₂ Emissions by Region + Energy Strategy")
plt.xticks(rotation=45)
plt.ylabel("CO₂ Emissions (tonnes per capita)")
plt.xlabel("Region and Energy Type")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

energy_types = df['energy_type'].unique()

plt.figure(figsize=(15, 5))

for i, energy in enumerate(energy_types, 1):
    plt.subplot(1, 3, i)  # 1 row, 3 columns
    sns.boxplot(data=df[df['energy_type'] == energy], x='region', y='co2_emissions')
    plt.title(f"CO₂ Emissions - {energy}")
    plt.ylabel("CO₂ Emissions (tonnes per capita)")
    plt.xlabel("Region")
    plt.tight_layout()

plt.show()
