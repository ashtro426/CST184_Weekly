# %%
# !pip3 install scikit-learn

import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Step 1: Simulated dataset (small, hardcoded)
data = {
    "Country": ["Nepal", "Kenya", "Germany", "India", "Australia", "Brazil"],
    "%Renewable": [88, 65, 45, 25, 35, 80],
    "CO2_per_capita": [1.2, 1.8, 6.5, 1.9, 17.0, 2.1],
    "Apply_Policy": ["yes", "yes", "no", "yes", "no", "yes"]
}

df = pd.DataFrame(data)

# Step 2: Encode the label for modeling
df["Label"] = df["Apply_Policy"].map({"yes": 1, "no": 0})

# Step 3: Define features and target
X = df[["%Renewable", "CO2_per_capita"]]
y = df["Label"]

# Step 4: Train the decision tree
tree = DecisionTreeClassifier(max_depth=3, random_state=0)
tree.fit(X, y)

# Step 5: Visualize the tree
plt.figure(figsize=(10, 6))
plot_tree(tree, feature_names=X.columns, class_names=["No", "Yes"], filled=True, rounded=True)
plt.title("Decision Tree – Apply Policy A")
plt.show()
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
