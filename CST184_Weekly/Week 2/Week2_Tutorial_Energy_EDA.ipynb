# %%
import pandas as pd

df = pd.read_csv("energy_cleaned.csv")
df.head()
# Out:
#      Country  %Renewable         Region
# 0      Nepal          89           Asia
# 1      India          45           Asia
# 2      Kenya          50         Africa
# 3     Brazil          95  South America
# 4  Australia          35        Oceania

# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv("energy_cleaned.csv")
# df.head()
# df.info()
# df.describe()

# %%
high_renew = df[df["%Renewable"] > 50]
print("Countries with >50% renewable energy:", len(high_renew))
# Out:
# Countries with >50% renewable energy: 2

# %%
high_renew = df[df["%Renewable"] > 70]
print("Countries with >50% renewable energy:", len(high_renew))
# Out:
# Countries with >50% renewable energy: 2

# %%
high_renew = df[df["%Renewable"] > 40]
print("Countries with >50% renewable energy:", len(high_renew))
# Out:
# Countries with >50% renewable energy: 5

# %%
region_avg = df.groupby("Region")["%Renewable"].mean()
print(region_avg)
# Out:
# Region
# Africa           50.0
# Asia             67.0
# Europe           48.0
# Oceania          35.0
# South America    95.0
# Name: %Renewable, dtype: float64

# %%
region_avg = df.groupby("Region")["%Renewable"].mean() .plot(kind='bar')
print(region_avg)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# South america

# %%
import matplotlib.pyplot as plt

df["%Renewable"].plot(kind="hist", bins=8, edgecolor="black")
plt.title("Histogram of Renewable Energy Use")
plt.xlabel("% Renewable")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

df["%Renewable"].plot(kind="hist", bins=5, edgecolor="black")
plt.title("Histogram of Renewable Energy Use")
plt.xlabel("% Renewable")
plt.grid(True)
plt.show()

# %%
# !pip install scipy
df["%Renewable"].plot(kind="density", linewidth=2)
plt.title("Density Plot of Renewable %")
plt.xlabel("% Renewable")
plt.grid(True)
plt.show()
# Out:
# Collecting scipy
#   Downloading scipy-1.16.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\ashli\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.1.3)
# Downloading scipy-1.16.2-cp312-cp312-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.6 MB 12.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.7/38.6 MB 11.9 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/38.6 MB 11.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/38.6 MB 11.7 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.6 MB 11.9 MB/s eta 0:00:03
#    --------------- ------------------------ 14.7/38.6 MB 11.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.3/38.6 MB 11.8 MB/s eta 0:00:02
#    -------------------- ------------------- 19.9/38.6 MB 11.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.3/38.6 MB 11.8 MB/s eta 0:00:02
#    ------------------------- -------------- 24.6/38.6 MB 11.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.0/38.6 MB 11.8 MB/s eta 0:00:01
#    ------------------------------ --------- 29.6/38.6 MB 11.8 MB/s eta 0:00:01
#    --------------------------------- ------ 32.2/38.6 MB 11.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.6 MB 11.8 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.6 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 11.7 MB/s  0:00:03
# Installing collected packages: scipy
# Successfully installed scipy-1.16.2

# %%
for region, group in df.groupby("Region"):
    if len(group) >= 2:
        group["%Renewable"].plot(kind="density", label=region)

plt.title("Renewable Energy by Region (KDE)")
plt.xlabel("% Renewable")
plt.legend()
plt.grid(True)
plt.show()
